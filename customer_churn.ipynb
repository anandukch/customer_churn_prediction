# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
df=pd.read_csv("customer_churn.csv")
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1227  8496-DMZUK    Male              0      No         No      30
# 5531  2137-DQMEV    Male              0     Yes        Yes      68
# 4215  9031-ZVQPT    Male              0     Yes         No      72
# 2497  5702-SKUOB  Female              0     Yes         No       4
# 5750  2398-YPMUR  Female              1     Yes         No      13
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1227          Yes               Yes     Fiber optic                  Yes  ...
# 5531           No  No phone service             DSL                  Yes  ...
# 4215          Yes               Yes     Fiber optic                   No  ...
# 2497          Yes                No              No  No internet service  ...
# 5750          Yes                No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 1227                  Yes                   No                   No
# 5531                   No                   No                  Yes
# 4215                  Yes                  Yes                  Yes
# 2497  No internet service  No internet service  No internet service
# 5750                   No                   No                   No
#
#           StreamingMovies        Contract PaperlessBilling  \
# 1227                   No        One year               No
# 5531                   No        One year               No
# 4215                  Yes        Two year              Yes
# 2497  No internet service  Month-to-month               No
# 5750                   No  Month-to-month              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges Churn
# 1227  Bank transfer (automatic)          90.40       2820.65    No
# 5531               Mailed check          44.80       2983.65    No
# 4215           Electronic check         108.20        7840.6    No
# 2497               Mailed check          19.60         93.45    No
# 5750           Electronic check          70.15        916.75   Yes
#
# [5 rows x 21 columns]

# %%
df.drop('customerID',axis='columns',inplace=True)

# %%
df.TotalCharges.values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
nullCharges = pd.to_numeric(df.TotalCharges,errors='coerce').isnull()

# %%
df[nullCharges]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# 753                 No              No  No internet service
# 936                 No             DSL                  Yes
# 1082               Yes              No  No internet service
# 1340  No phone service             DSL                  Yes
# 3331                No              No  No internet service
# 3826               Yes              No  No internet service
# 4380                No              No  No internet service
# 5218                No              No  No internet service
# 6670               Yes             DSL                   No
# 6754               Yes             DSL                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 488                    No                  Yes                  Yes
# 753   No internet service  No internet service  No internet service
# 936                   Yes                  Yes                   No
# 1082  No internet service  No internet service  No internet service
# 1340                  Yes                  Yes                  Yes
# 3331  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 6670                  Yes                  Yes                  Yes
# 6754                  Yes                   No                  Yes
#
#               StreamingTV      StreamingMovies  Contract PaperlessBilling  \
# 488                   Yes                   No  Two year              Yes
# 753   No internet service  No internet service  Two year               No
# 936                   Yes                  Yes  Two year               No
# 1082  No internet service  No internet service  Two year               No
# 1340                  Yes                   No  Two year               No
# 3331  No internet service  No internet service  Two year               No
# 3826  No internet service  No internet service  Two year               No
# 4380  No internet service  No internet service  Two year               No
# 5218  No internet service  No internet service  One year              Yes
# 6670                  Yes                   No  Two year               No
# 6754                   No                   No  Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 488   Bank transfer (automatic)           52.55                 No
# 753                Mailed check           20.25                 No
# 936                Mailed check           80.85                 No
# 1082               Mailed check           25.75                 No
# 1340    Credit card (automatic)           56.05                 No
# 3331               Mailed check           19.85                 No
# 3826               Mailed check           25.35                 No
# 4380               Mailed check           20.00                 No
# 5218               Mailed check           19.70                 No
# 6670               Mailed check           73.35                 No
# 6754  Bank transfer (automatic)           61.90                 No

# %%
df1 = df[df.TotalCharges!=' ']

# %%
df1.TotalCharges=pd.to_numeric(df1.TotalCharges)
# Out:
# /tmp/ipykernel_3273/695980592.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.TotalCharges=pd.to_numeric(df1.TotalCharges)

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
df1[df1.Churn=='No']
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 3       Male              0      No         No      45           No
# 6       Male              0      No        Yes      22          Yes
# 7     Female              0      No         No      10           No
# ...      ...            ...     ...        ...     ...          ...
# 7037  Female              0      No         No      72          Yes
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 0     No phone service             DSL                   No
# 1                   No             DSL                  Yes
# 3     No phone service             DSL                  Yes
# 6                  Yes     Fiber optic                   No
# 7     No phone service             DSL                  Yes
# ...                ...             ...                  ...
# 7037                No              No  No internet service
# 7038               Yes             DSL                  Yes
# 7039               Yes     Fiber optic                   No
# 7040  No phone service             DSL                  Yes
# 7042                No     Fiber optic                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 0                     Yes                   No                   No
# 1                      No                  Yes                   No
# 3                      No                  Yes                  Yes
# 6                     Yes                   No                   No
# 7                      No                   No                   No
# ...                   ...                  ...                  ...
# 7037  No internet service  No internet service  No internet service
# 7038                   No                  Yes                  Yes
# 7039                  Yes                  Yes                   No
# 7040                   No                   No                   No
# 7042                   No                  Yes                  Yes
#
#               StreamingTV      StreamingMovies        Contract  \
# 0                      No                   No  Month-to-month
# 1                      No                   No        One year
# 3                      No                   No        One year
# 6                     Yes                   No  Month-to-month
# 7                      No                   No  Month-to-month
# ...                   ...                  ...             ...
# 7037  No internet service  No internet service        Two year
# 7038                  Yes                  Yes        One year
# 7039                  Yes                  Yes        One year
# 7040                   No                   No  Month-to-month
# 7042                  Yes                  Yes        Two year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 0                 Yes           Electronic check           29.85
# 1                  No               Mailed check           56.95
# 3                  No  Bank transfer (automatic)           42.30
# 6                 Yes    Credit card (automatic)           89.10
# 7                  No               Mailed check           29.75
# ...               ...                        ...             ...
# 7037              Yes  Bank transfer (automatic)           21.15
# 7038              Yes               Mailed check           84.80
# 7039              Yes    Credit card (automatic)          103.20
# 7040              Yes           Electronic check           29.60
# 7042              Yes  Bank transfer (automatic)          105.65
#
#       TotalCharges Churn
# 0            29.85    No
# 1          1889.50    No
# 3          1840.75    No
# 6          1949.40    No
# 7           301.90    No
# ...            ...   ...
# 7037       1419.40    No
# 7038       1990.50    No
# 7039       7362.90    No
# 7040        346.45    No
# 7042       6844.50    No
#
# [5163 rows x 20 columns]

# %%
tenure_churn_no = df1[df1.Churn=='No'].tenure
tenure_churn_yes = df1[df1.Churn=='Yes'].tenure

plt.xlabel("tenure")
plt.ylabel("Number Of Customers")

plt.hist([tenure_churn_yes, tenure_churn_no], rwidth=0.95, color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %%
mc_churn_no = df1[df1.Churn=='No'].MonthlyCharges      
mc_churn_yes = df1[df1.Churn=='Yes'].MonthlyCharges      

plt.xlabel("Monthly Charges")
plt.ylabel("Number Of Customers")
plt.title("Customer Churn Prediction Visualiztion")

plt.hist([mc_churn_yes, mc_churn_no], rwidth=0.95, color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %%
df1.replace('No internet service','No',inplace=True)
df1.replace('No phone service','No',inplace=True)
# Out:
# /tmp/ipykernel_3273/2045096646.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No internet service','No',inplace=True)
# /tmp/ipykernel_3273/2045096646.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No phone service','No',inplace=True)

# %%
def print_unquie_col_values(df):
    # res={}
    for col in df:
        if df[col].dtypes=='object':
            print(f'{col}:{df[col].unique()}')

    # return res

# %%
print_unquie_col_values(df1)
# Out:
# MultipleLines:['No' 0 1]
# InternetService:['DSL' 'Fiber optic' 'No']
# OnlineSecurity:[0 1 'No']
# OnlineBackup:[1 0 'No']
# DeviceProtection:[0 1 'No']
# TechSupport:[0 1 'No']
# StreamingTV:[0 1 'No']
# StreamingMovies:[0 1 'No']
# Contract:['Month-to-month' 'One year' 'Two year']
# PaymentMethod:['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']

# %%
yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup',
                  'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']
for col in yes_no_columns:
    df1[col].replace({'Yes': 1,'No': 0},inplace=True)
# Out:
# /tmp/ipykernel_3273/1648037665.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace({'Yes': 1,'No': 0},inplace=True)

# %%
df1['gender'].replace({'Female':1,'Male':0},inplace=True)
# Out:
# /tmp/ipykernel_3273/698335744.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['gender'].replace({'Female':1,'Male':0},inplace=True)

# %%
df1.gender.unique()
# Out:
# array([1, 0])

# %%
for col in df1:
    print(f'{col}: {df1[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: [1 0]
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]

# %%
df2 = pd.get_dummies(data=df1, columns=['InternetService','Contract','PaymentMethod'],dtype=int)
df2.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 5089       0              0        1           1       8             1
# 5474       1              0        0           0       1             1
# 4282       1              0        1           1      52             1
# 1538       0              0        0           0       8             1
# 5434       0              0        0           1      33             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 5089              0               0             0                 0  ...
# 5474              1               0             0                 0  ...
# 4282              1               0             0                 1  ...
# 1538              1               0             1                 0  ...
# 5434              1               1             0                 1  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 5089                    1                            0                   0
# 5474                    0                            1                   0
# 4282                    0                            1                   0
# 1538                    0                            1                   0
# 5434                    0                            1                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 5089                        1                  0                  0
# 5474                        1                  0                  0
# 4282                        0                  1                  0
# 1538                        1                  0                  0
# 5434                        1                  0                  0
#
#       PaymentMethod_Bank transfer (automatic)  \
# 5089                                        0
# 5474                                        0
# 4282                                        1
# 1538                                        0
# 5434                                        1
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 5089                                      0                               1
# 5474                                      0                               1
# 4282                                      0                               0
# 1538                                      0                               1
# 5434                                      0                               0
#
#       PaymentMethod_Mailed check
# 5089                           0
# 5474                           0
# 4282                           0
# 1538                           0
# 5434                           0
#
# [5 rows x 27 columns]

# %%
cols_to_scale= ['tenure','MonthlyCharges','TotalCharges']
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])

# %%
for col in df2:
    print(f'{col}:{df2[col].unique()}')
# Out:
# gender:[1 0]
# SeniorCitizen:[0 1]
# Partner:[1 0]
# Dependents:[0 1]
# tenure:[0.         0.46478873 0.01408451 0.61971831 0.09859155 0.29577465
#  0.12676056 0.38028169 0.85915493 0.16901408 0.21126761 0.8028169
#  0.67605634 0.33802817 0.95774648 0.71830986 0.98591549 0.28169014
#  0.15492958 0.4084507  0.64788732 1.         0.22535211 0.36619718
#  0.05633803 0.63380282 0.14084507 0.97183099 0.87323944 0.5915493
#  0.1971831  0.83098592 0.23943662 0.91549296 0.11267606 0.02816901
#  0.42253521 0.69014085 0.88732394 0.77464789 0.08450704 0.57746479
#  0.47887324 0.66197183 0.3943662  0.90140845 0.52112676 0.94366197
#  0.43661972 0.76056338 0.50704225 0.49295775 0.56338028 0.07042254
#  0.04225352 0.45070423 0.92957746 0.30985915 0.78873239 0.84507042
#  0.18309859 0.26760563 0.73239437 0.54929577 0.81690141 0.32394366
#  0.6056338  0.25352113 0.74647887 0.70422535 0.35211268 0.53521127]
# PhoneService:[0 1]
# MultipleLines:[0 1]
# OnlineSecurity:[0 1]
# OnlineBackup:[1 0]
# DeviceProtection:[0 1]
# TechSupport:[0 1]
# StreamingTV:[0 1]
# StreamingMovies:[0 1]
# PaperlessBilling:[1 0]
# MonthlyCharges:[0.11542289 0.38507463 0.35422886 ... 0.44626866 0.25820896 0.60149254]
# TotalCharges:[0.0012751  0.21586661 0.01031041 ... 0.03780868 0.03321025 0.78764136]
# Churn:[0 1]
# InternetService_DSL:[1 0]
# InternetService_Fiber optic:[0 1]
# InternetService_No:[0 1]
# Contract_Month-to-month:[1 0]
# Contract_One year:[0 1]
# Contract_Two year:[0 1]
# PaymentMethod_Bank transfer (automatic):[0 1]
# PaymentMethod_Credit card (automatic):[0 1]
# PaymentMethod_Electronic check:[1 0]
# PaymentMethod_Mailed check:[0 1]

# %%
X = df2.drop('Churn',axis='columns')
y=df2['Churn']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.2,random_state=5)

# %%
X_train[:3]
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 5664       1              1        0           0  0.126761             1
# 101        1              0        1           1  0.000000             1
# 2621       0              0        1           0  0.985915             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 5664              0               0             0                 1  ...
# 101               0               0             0                 0  ...
# 2621              0               0             1                 1  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 5664                    0                            1                   0
# 101                     0                            0                   1
# 2621                    1                            0                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 5664                        1                  0                  0
# 101                         1                  0                  0
# 2621                        0                  0                  1
#
#       PaymentMethod_Bank transfer (automatic)  \
# 5664                                        0
# 101                                         0
# 2621                                        0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 5664                                      1                               0
# 101                                       0                               1
# 2621                                      1                               0
#
#       PaymentMethod_Mailed check
# 5664                           0
# 101                            0
# 2621                           0
#
# [3 rows x 26 columns]

# %%
len(X_train.columns)
# Out:
# 26

# %%
import tensorflow as tf
from tensorflow import keras

model= keras.Sequential([
    keras.layers.Dense(26,input_shape=(26,),activation='relu'),
    keras.layers.Dense(15,activation='relu'),
    keras.layers.Dense(1,activation='sigmoid')    
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100)
# Out:
# 2023-09-07 18:43:50.275560: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-07 18:43:50.285102: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Epoch 1/100
# 176/176 [==============================] - 1s 1ms/step - loss: 0.4812 - accuracy: 0.7620
# Epoch 2/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4292 - accuracy: 0.8005
# Epoch 3/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4213 - accuracy: 0.8018
# Epoch 4/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4173 - accuracy: 0.8023
# Epoch 5/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4139 - accuracy: 0.8071
# Epoch 6/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4117 - accuracy: 0.8034
# Epoch 7/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4094 - accuracy: 0.8057
# Epoch 8/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4093 - accuracy: 0.8071
# Epoch 9/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4063 - accuracy: 0.8107
# Epoch 10/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4049 - accuracy: 0.8071
# Epoch 11/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4041 - accuracy: 0.8108
# Epoch 12/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4028 - accuracy: 0.8094
# Epoch 13/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4012 - accuracy: 0.8124
# Epoch 14/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4002 - accuracy: 0.8130
# Epoch 15/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3991 - accuracy: 0.8155
# Epoch 16/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3988 - accuracy: 0.8164
# Epoch 17/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3969 - accuracy: 0.8124
# Epoch 18/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3958 - accuracy: 0.8139
# Epoch 19/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3948 - accuracy: 0.8158
# Epoch 20/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3931 - accuracy: 0.8160
# Epoch 21/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3929 - accuracy: 0.8165
# Epoch 22/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3922 - accuracy: 0.8178
# Epoch 23/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3917 - accuracy: 0.8178
# Epoch 24/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3900 - accuracy: 0.8192
# Epoch 25/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3901 - accuracy: 0.8171
# Epoch 26/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3882 - accuracy: 0.8190
# Epoch 27/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3877 - accuracy: 0.8171
# Epoch 28/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3883 - accuracy: 0.8185
# Epoch 29/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3867 - accuracy: 0.8172
# Epoch 30/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3853 - accuracy: 0.8210
# Epoch 31/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3837 - accuracy: 0.8201
# Epoch 32/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3835 - accuracy: 0.8194
# Epoch 33/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3828 - accuracy: 0.8194
# Epoch 34/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3822 - accuracy: 0.8206
# Epoch 35/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3822 - accuracy: 0.8197
# Epoch 36/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3815 - accuracy: 0.8219
# Epoch 37/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3800 - accuracy: 0.8226
# Epoch 38/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3795 - accuracy: 0.8203
# Epoch 39/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3784 - accuracy: 0.8231
# Epoch 40/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3785 - accuracy: 0.8201
# Epoch 41/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3776 - accuracy: 0.8236
# Epoch 42/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3760 - accuracy: 0.8236
# Epoch 43/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3751 - accuracy: 0.8247
# Epoch 44/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3761 - accuracy: 0.8217
# Epoch 45/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3762 - accuracy: 0.8201
# Epoch 46/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3746 - accuracy: 0.8228
# Epoch 47/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3737 - accuracy: 0.8220
# Epoch 48/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3739 - accuracy: 0.8292
# Epoch 49/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3729 - accuracy: 0.8226
# Epoch 50/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3723 - accuracy: 0.8247
# Epoch 51/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3716 - accuracy: 0.8258
# Epoch 52/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3713 - accuracy: 0.8254
# Epoch 53/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3709 - accuracy: 0.8267
# Epoch 54/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3702 - accuracy: 0.8261
# Epoch 55/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3692 - accuracy: 0.8254
# Epoch 56/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3688 - accuracy: 0.8281
# Epoch 57/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3689 - accuracy: 0.8286
# Epoch 58/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3678 - accuracy: 0.8251
# Epoch 59/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3680 - accuracy: 0.8236
# Epoch 60/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3666 - accuracy: 0.8270
# Epoch 61/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3659 - accuracy: 0.8274
# Epoch 62/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3656 - accuracy: 0.8256
# Epoch 63/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3650 - accuracy: 0.8290
# Epoch 64/100
# 176/176 [==============================] - 0s 991us/step - loss: 0.3650 - accuracy: 0.8286
# Epoch 65/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3635 - accuracy: 0.8272
# Epoch 66/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3646 - accuracy: 0.8283
# Epoch 67/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3640 - accuracy: 0.8293
# Epoch 68/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3622 - accuracy: 0.8315
# Epoch 69/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3617 - accuracy: 0.8267
# Epoch 70/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3610 - accuracy: 0.8306
# Epoch 71/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3605 - accuracy: 0.8297
# Epoch 72/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3600 - accuracy: 0.8318
# Epoch 73/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3598 - accuracy: 0.8341
# Epoch 74/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3586 - accuracy: 0.8331
# Epoch 75/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3589 - accuracy: 0.8284
# Epoch 76/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3579 - accuracy: 0.8318
# Epoch 77/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3575 - accuracy: 0.8336
# Epoch 78/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3573 - accuracy: 0.8324
# Epoch 79/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3575 - accuracy: 0.8316
# Epoch 80/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3562 - accuracy: 0.8343
# Epoch 81/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3558 - accuracy: 0.8325
# Epoch 82/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3551 - accuracy: 0.8341
# Epoch 83/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3552 - accuracy: 0.8357
# Epoch 84/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3546 - accuracy: 0.8311
# Epoch 85/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3538 - accuracy: 0.8334
# Epoch 86/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3526 - accuracy: 0.8327
# Epoch 87/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3551 - accuracy: 0.8338
# Epoch 88/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3523 - accuracy: 0.8340
# Epoch 89/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3523 - accuracy: 0.8338
# Epoch 90/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3519 - accuracy: 0.8343
# Epoch 91/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3508 - accuracy: 0.8343
# Epoch 92/100
# 176/176 [==============================] - 0s 988us/step - loss: 0.3517 - accuracy: 0.8350
# Epoch 93/100
# 176/176 [==============================] - 0s 974us/step - loss: 0.3498 - accuracy: 0.8363
# Epoch 94/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3492 - accuracy: 0.8313
# Epoch 95/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3479 - accuracy: 0.8366
# Epoch 96/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3492 - accuracy: 0.8366
# Epoch 97/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3497 - accuracy: 0.8350
# Epoch 98/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3482 - accuracy: 0.8338
# Epoch 99/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3480 - accuracy: 0.8345
# Epoch 100/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3468 - accuracy: 0.8370

# %%
model.evaluate(X_test,y_test)
# Out:
# 44/44 [==============================] - 0s 841us/step - loss: 0.4788 - accuracy: 0.7783
# [0.478828102350235, 0.778251588344574]

# %%
yp=model.predict(X_test)
# Out:
# 44/44 [==============================] - 0s 660us/step

# %%
y_pred=[]
for i in yp:
    if i>0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)
y_pred[:9]
# Out:
# [0, 1, 0, 1, 0, 1, 0, 0, 0]

# %%
y_test[:9]
# Out:
# 2660    0
# 744     0
# 5579    1
# 64      1
# 3287    1
# 816     1
# 2670    0
# 5920    0
# 1023    0
# Name: Churn, dtype: int64

# %%
from sklearn.metrics import confusion_matrix , classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.84       999
#            1       0.62      0.61      0.61       408
#
#     accuracy                           0.78      1407
#    macro avg       0.73      0.73      0.73      1407
# weighted avg       0.78      0.78      0.78      1407

# %%
import seaborn as sn
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred)

plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')
